# %% [markdown]
# <a href="https://colab.research.google.com/github/YASHASVASISHTA/AI-PROJECTS/blob/main/Langraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("⏳ Starting environment setup... Please wait.")

# 1. Install core LangGraph and LangChain libraries quietly (-q)
# !pip install -q langgraph langchain-core

# 2. Install helper utilities for displaying and processing images/flowcharts
# !pip install -q pillow requests

print("✅ Installation complete!")
# Out:
# ⏳ Starting environment setup... Please wait.
# ✅ Installation complete!

# %%
# ==========================================
#  VERIFY INSTALLATION
# ==========================================

import sys

try:
    from langgraph.graph import StateGraph, START, END
    from typing_extensions import TypedDict
    import langchain_core

    print(f"• Python Version: {sys.version.split()[0]}")
    print(f"• LangChain Core Version: {langchain_core.__version__}")
    print("\nEverything is configured correctly. You are ready to build your graph!")

except ImportError as e:
    print("❌ ERROR: Installation verification failed.")
    print(f"Missing dependency or import error: {e}")
    print("Tip: Go back to Cell 1, run it again, and ensure it finishes without errors.")
# Out:
# • Python Version: 3.12.13
# • LangChain Core Version: 1.4.3
#
# Everything is configured correctly. You are ready to build your graph!
